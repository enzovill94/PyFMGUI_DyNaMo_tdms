# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import os
import pyfmreader as pyfm
import pyfmreader.ps_nex.parseTDMS as tdms
import numpy as np
import pyfmreader.ps_nex.loadpsnexMaps as maps

# %%
# analyze CTC44 maps
file_path = '/Users/evillz/Data/CTC44/CTC_chirp_yogesh/psnex_map___2025.03.21_19.44.03.14'


file_path = '/Users/evillz/Data/CTC44/2025_12_03/psnex_map___2025.03.12_17.32.40.55' # this is cool

file_path = '/Users/evillz/Data/CTC44/2025_12_03/psnex_map___2025.03.12_17.51.51.34' # is okay...

file_path = '/Users/evillz/Data/CTC44/2025_12_03/psnex_map___2025.03.12_18.38.42.45' # CTC 44 PFQNM. THIS

# %%
# file_path = '/Volumes/SSK_Drive/2026_map_ctc44_3d/2026_04_23/sample3/calibration_glass/psnex_map___2026.04.23_18.23.29.37'

# %%
# import os
# Get Metadata
# file = os.path.dirname(map_path)    
# print (file)
_, tdms_files = tdms.grab_tdms(file_path)
print(tdms_files[1])
psnex_file = pyfm.loadfile(tdms_files[1]) # load the second file. First file gives error becomes sometimes is zero kb size


# Get metadata and force curve object
metadata = psnex_file.filemetadata
# print (metadata)
# for data in metadata :
#     print (data, metadata[data])    

# get mapping parameters
curve_prop = metadata['curve_properties']['0']
map_x_init= metadata["mapping_X_initial_pos_V"]
map_y_init= metadata["mapping_Y_initial_pos_V"]
map_x_step = metadata["mapping_X_step_size_V"]
map_y_step = metadata["mapping_Y_step_size_V"]
map_x_cur = metadata["X_cur_position_V"]
map_y_cur = metadata["Y_cur_position_V"]
# map_x_pix = 32
# map_y_pix = 32
# print (curve_prop)

# Get sensitivities
z_stage_sens = metadata['curve_properties']['0'][0]['z_stage_sensitivity']
z_setpoint_trig_v  = metadata['curve_properties']['0'][0]['segment_0_Z_position_setpoint_trigger_(V)']
x_sens_nm = metadata['system_X_piezo_sensitivity_(nm/V)']
y_sens_nm = metadata['system_Y_piezo_sensitivity_(nm/V)']
x_sens_um = x_sens_nm/1000
y_sens_um = y_sens_nm/1000
# for data in curve_prop :
#     print (data, curve_prop[data])
# Out:
# /Users/evillz/Data/CTC44/2025_12_03/psnex_map___2025.03.12_18.38.42.45/fcurve___2025.03.12_18.40.03.65.tdms
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0

# %%
import time

# Initialize lists to store the parameters
z_setpoint_trig_v_list = []
mapping_index_list = []
map_x_index_list = []
map_y_index_list = []
map_x_pos_v_list = []
map_y_pos_v_list = []
impulse_xy_v = 0.1
estimate_xy = True

# Open each force curve in the map and read the Zposition contact. If file is corrupt, NaN will be placed
for files in tdms_files:
    # start_time = time.time()  # Start timing
    try:
        psnex_file = pyfm.loadfile(files)  # load the file
        # Get metadata and force curve object
        metadata = psnex_file.filemetadata
        z_setpoint_trig_v = metadata['curve_properties']['0'][0]['segment_0_Z_position_setpoint_trigger_(V)']
        mapping_index = metadata['mapping_index']
        map_x_index = metadata['mapping_position_X']
        map_y_index = metadata['mapping_position_Y']
        map_x_pos_v = metadata['X_cur_position_V']
        map_y_pos_v = metadata['Y_cur_position_V']
       
        # Z height contact and setpoint
        z_setpoint_trig_v  = metadata['curve_properties']['0'][0]['segment_0_Z_position_setpoint_trigger_(V)']
        
        # Get sensitivities if not already loaded
        if 'z_stage_sens_nm_V' not in locals():
            z_stage_sens_nm_V = metadata['curve_properties']['0'][0]['z_stage_sensitivity']
        if 'x_sens_nm' not in locals():
            x_sens_nm = metadata['system_X_piezo_sensitivity_(nm/V)']
        if 'y_sens_nm' not in locals():
            y_sens_nm = metadata['system_Y_piezo_sensitivity_(nm/V)']
        if 'x_sens_um' not in locals():
            x_sens_um = x_sens_nm / 1000
        if 'y_sens_um' not in locals():
            y_sens_um = y_sens_nm / 1000
        
        # Append the parameters to the lists
        z_setpoint_trig_v_list.append(float(z_setpoint_trig_v))
        mapping_index_list.append(mapping_index)
        map_x_index_list.append(map_x_index)
        map_y_index_list.append(map_y_index)
        map_x_pos_v_list.append(map_x_pos_v)
        map_y_pos_v_list.append(map_y_pos_v)
    except Exception as e:
        print(f"Error loading file {files}: {e}")
        # Append NaN to the lists if there is an error
        z_setpoint_trig_v_list.append(np.nan)
        mapping_index_list.append(np.nan)
        map_x_index_list.append(np.nan)
        map_y_index_list.append(np.nan)
        map_x_pos_v_list.append(np.nan)
        map_y_pos_v_list.append(np.nan)
    # end_time = time.time()  # End timing
    # iteration_time = end_time - start_time
    # print(f"Time for iteration: {iteration_time:.4f} seconds")

z_height_um_list = [z * z_stage_sens_nm_V * 1e-3 for z in z_setpoint_trig_v_list]

if estimate_xy:
    x_pos_um_list = [x * x_sens_um * impulse_xy_v for x in map_x_index_list]
    y_pos_um_list = [y * y_sens_um * impulse_xy_v for y in map_y_index_list]
else:
    x_pos_um_list = [x * x_sens_um * impulse_xy_v for x in map_x_pos_v_list]
    y_pos_um_list = [y * y_sens_um * impulse_xy_v for y in map_y_pos_v_list]

# Create a dictionary with the parameters
data = {
    'filepath': tdms_files,
    'filename': [os.path.basename(file) for file in tdms_files],
    'z_height_v': z_setpoint_trig_v_list,
    'curve_index': mapping_index_list,
    'x_index': map_x_index_list,
    'y_index': map_y_index_list,
    'x_pos_v': map_x_pos_v_list,
    'y_pos_v': map_y_pos_v_list,
    'z_height_um': z_height_um_list,
    'x_pos_um': x_pos_um_list,
    'y_pos_um': map_y_pos_v_list, 
}

# Convert the dictionary to a DataFrame
df = pd.DataFrame(data)

estimated_square = np.sqrt(len(tdms_files))
print (f'# of files analyzed: {len(tdms_files)}, square root is : {estimated_square}')
map_x_pix = int(estimated_square)
map_y_pix = int(estimated_square)
# Out:
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ...
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# # of files analyzed: 1024, square root is : 32.0

# %%
print(df.head())

df_sorted = df.sort_values(by='curve_index')
x_pos_um_sorted = df_sorted['x_pos_um'].values
y_pos_um_sorted = df_sorted['y_pos_um'].values
z_height_um_sorted = df_sorted['z_height_um'].values
# Out:
#                                             filepath  \
# 0  /Users/evillz/Data/CTC44/2025_12_03/psnex_map_...
# 1  /Users/evillz/Data/CTC44/2025_12_03/psnex_map_...
# 2  /Users/evillz/Data/CTC44/2025_12_03/psnex_map_...
# 3  /Users/evillz/Data/CTC44/2025_12_03/psnex_map_...
# 4  /Users/evillz/Data/CTC44/2025_12_03/psnex_map_...
#
#                                filename  z_height_v  curve_index  x_index  \
# 0  fcurve___2025.03.12_18.40.02.93.tdms    5.799927            0        0
# 1  fcurve___2025.03.12_18.40.03.65.tdms    5.806519            1        1
# 2  fcurve___2025.03.12_18.40.04.36.tdms    6.023285            2        2
# 3  fcurve___2025.03.12_18.40.04.94.tdms    6.029541            3        3
# 4  fcurve___2025.03.12_18.40.06.16.tdms    6.119629            5        5
#
#    y_index   x_pos_v  y_pos_v  z_height_um  x_pos_um  y_pos_um
# 0        0  0.000000      0.0    34.799562    0.0000       0.0
# 1        0  0.157302      0.0    34.839114    0.5685       0.0
# 2        0  0.314604      0.0    36.139710    1.1370       0.0
# 3        0  0.471906      0.0    36.177246    1.7055       0.0
# 4        0  0.786510      0.0    36.717774    2.8425       0.0

# %%
# convert dataframe to dictiontionary
map = {
    'filepath': df_sorted['filepath'].values,
    'filename': df_sorted['filename'].values,
    'z_height_v': df_sorted['z_height_v'].values,
    'curve_index': df_sorted['curve_index'].values,
    'x_index': df_sorted['x_index'].values,
    'y_index': df_sorted['y_index'].values,
    'x_pos_v': df_sorted['x_pos_v'].values,
    'y_pos_v': df_sorted['y_pos_v'].values,
    'z_height_um': df_sorted['z_height_um'].values,
    'x_pos_um': df_sorted['x_pos_um'].values,
    'y_pos_um': df_sorted['y_pos_um'].values, 
    'map_x_pix': map_x_pix,
    'map_y_pix': map_y_pix,
    'x_sens_nm': x_sens_nm,
    'y_sens_nm': y_sens_nm,
    'z_stage_sens_nm_V': z_stage_sens_nm_V,
}

# %%
_ = maps.analyze_map_dimension(map, map_x_pix, map_y_pix)
# Out:
# <class 'dict'>
# Dictionary structure: dict_keys(['filepath', 'filename', 'z_height_v', 'curve_index', 'x_index', 'y_index', 'x_pos_v', 'y_pos_v', 'z_height_um', 'x_pos_um', 'y_pos_um', 'map_x_pix', 'map_y_pix', 'x_sens_nm', 'y_sens_nm', 'z_stage_sens_nm_V'])
# Length of df: 16
# Size of z_height_um column: 1024
# Shape of data: 32 x 32 = 1024
# Data dimensions match the expected shape.

# %%
# Get final data files
x_axis = x_pos_um_sorted[:map_x_pix].round(1)
y_axis = np.reshape(y_pos_um_sorted, (map_x_pix, map_y_pix))[:,0].round(1)
z_pos_2d = np.reshape(z_height_um_sorted, (map_x_pix, map_y_pix)) 

# remove the last column from all 

print(x_axis)

# Normalize both axes
x_axis_normalized = (x_axis - x_axis.min()) / (x_axis.max() - x_axis.min())
y_axis_normalized = (y_axis - y_axis.min()) / (y_axis.max() - y_axis.min())

# Specify the normalization
print("X-axis normalized to range [0, 1]")
print("Y-axis normalized to range [0, 1]")

# Mirror flip the 2D array along the vertical axis
z_pos_2d_flipped = np.flip(z_pos_2d, axis=1)

# Zero height to represent the actual height since the height is calculated as the approach 
map_test_um_zeroed = -z_pos_2d_flipped + z_pos_2d_flipped.max().max()

fig, ax = plt.subplots(figsize=(20, 10))  # Adjust the figsize as needed
a = sns.heatmap(map_test_um_zeroed, xticklabels=x_axis_normalized.round(2), yticklabels=y_axis_normalized.round(2), ax=ax, cmap="YlOrBr")
a.invert_yaxis()

a.set_xlabel('Normalized X axis')
a.set_ylabel('Normalized Y axis')
# a.set_title(f'Heatmap: {filename}')

colorbar = a.collections[0].colorbar
colorbar.set_label('Z axis (um)')
colorbar.ax.yaxis.label.set_rotation(90)  # Rotate the Z axis label
_ = plt.xticks(ticks=np.arange(0, len(x_axis_normalized), 5), labels=x_axis_normalized[::5].round(2), rotation=45)
_ = plt.yticks(ticks=np.arange(0, len(y_axis_normalized), 5), labels=y_axis_normalized[::5].round(2), rotation=0)

# Show minor ticks
ax.minorticks_on()
ax.tick_params(axis='both', which='minor', length=4, color='black')

# Set transparent background
fig.patch.set_alpha(0.0)
# Out:
# [ 0.   0.6  1.1  1.7  2.3  2.8  3.4  4.   4.5  5.1  5.7  6.3  6.8  7.4
#   8.   8.5  9.1  9.7 10.2 10.8 11.4 11.9 12.5 13.1 13.6 14.2 14.8 15.3
#  15.9 16.5 17.1 17.6]
# X-axis normalized to range [0, 1]
# Y-axis normalized to range [0, 1]

# %%
# Define the z-axis range for the colormap
z_min = map_test_um_zeroed.min().min()  # Minimum value in the DataFrame
z_max = map_test_um_zeroed.max().max()  # Maximum value in the DataFrame

# Set the range for the colormap
vmin = z_min
vmax = z_max

fig, ax = plt.subplots(figsize=(20, 10))  # Adjust the figsize as needed
a = sns.heatmap(map_test_um_zeroed, xticklabels=x_axis.round(2), yticklabels=y_axis.round(2), ax=ax, cmap="YlOrBr", vmin=vmin, vmax=vmax)
a.invert_yaxis()
a.set_aspect((y_sens_um / x_sens_um) ** -1)

a.set_xlabel('X axis (um)', fontsize=20)
a.set_ylabel('Y axis (um)', fontsize=20)
# a.set_title(f'Heatmap: {filename}')


colorbar = a.collections[0].colorbar
colorbar.set_label('Z axis (um)', fontsize=18)

colorbar.ax.yaxis.label.set_rotation(90)  # Rotate the Z axis label
_ = plt.xticks(ticks=np.arange(0, len(x_axis), 5), labels=x_axis[::5].round(1), rotation=45, fontsize=26)
_ = plt.yticks(ticks=np.arange(0, len(y_axis), 5), labels=y_axis[::5].round(1), rotation=0, fontsize=26)
# set font size for Z ticks
colorbar.ax.tick_params(labelsize=26)


# Limit the y-axis to show only values up to 2.9 µm
ylim = 2.9
ax.set_ylim(0, np.where(y_axis <= ylim)[0][-1] + 1)

# Limit the x-axis to show only values up to 15.0 µm
xlim = 17
ax.set_xlim(0, np.where(x_axis <= xlim)[0][-1] + 1)

# Show minor ticks
ax.minorticks_on()
ax.tick_params(axis='both', which='minor', length=4, color='black')

# Set transparent background
fig.patch.set_alpha(0.0)

# %%
# map_path = '/Users/evillz/Data/psnex_map___2025.03.12_18.23.11.20/CTC45_map1_PFQNM.csv'
map_path = '/Volumes/SSK_Drive/2026_map_ctc44_3d/2026_11_04_test/psnex_map___2025.11.04_16.50.31.27/psnex_map___2025.11.04_16.50.31.27.csv'

# %%
import glob
import os

# Define the directory path
file_path = '/Users/evillz/Data/psnex_map___2025.03.12_18.23.11.20'
# file_path = '/Volumes/SSK_Drive/2026_map_ctc44_3d/2026_11_04_test/psnex_map___2025.11.04_16.50.31.27'

# Use glob to find all .csv files in the directory
csv_files = glob.glob(os.path.join(file_path, '*.csv'))

# Check if any CSV files were found
if not csv_files:
    print("No CSV files found")
else:
    # Print the list of .csv files found
    for file in csv_files:
        print(file)

map_path = csv_files[0]
# Out:
# /Users/evillz/Data/psnex_map___2025.03.12_18.23.11.20/CTC45_map1_PFQNM.csv

# %%
map_test = pd.read_csv(map_path,header=None)
print (map_path)

filename = os.path.basename(map_path).replace('.csv', '')
print(filename)

map_test = map_test.dropna()
z_sens_um = 6 # um/V
map_test_um =map_test * z_sens_um

impulse_v = 1

map_dx_v = map_x_step
map_dy_v = map_y_step

x_sens_nm = 5685   # um/V
y_sens_nm = 3960   # um/V

x_sens_um = x_sens_nm/1000
y_sens_um = y_sens_nm/1000  

print (x_sens_um, y_sens_um)
print(map_test.shape)
# Out:
# /Users/evillz/Data/psnex_map___2025.03.12_18.23.11.20/CTC45_map1_PFQNM.csv
# CTC45_map1_PFQNM
# 5.685 3.96
# (32, 32)

# %%
# Convert map_test to a numpy array
map_test_array = map_test.values

# Compare the map_test_array: contact position from the files loaded with respect to z_pos_2d : the image saved
arrays_equal = np.array_equal(z_pos_2d_flipped, map_test_array)
print("Are z_pos_2d and map_test_array the same?", arrays_equal)
# Out:
# Are z_pos_2d and map_test_array the same? False

# %% [markdown]
# To open CSV map files run this part of the code

# %%
map_test = pd.read_csv(map_path,header=None)


map_test = map_test.dropna()
z_sens_um = 6 # um/V
map_test_um =map_test * z_sens_um

impulse_v = 1

map_dx_v = map_x_step
map_dy_v = map_y_step

x_sens_nm = 5685   # um/V
y_sens_nm = 3960   # um/V

x_sens_um = x_sens_nm/1000
y_sens_um = y_sens_nm/1000  

print (x_sens_um, y_sens_um)
# Out:
# 5.685 3.96

# %%
map_test_um_zeroed = -map_test_um + map_test_um.max().max()
# print(map_test_um_zeroed)

# plot map_test_um_zeroed and map_test_um on matplotlib
# fig, ax = plt.subplots(figsize=(15, 5))
# plt.plot(map_test_um_zeroed)
# plt.plot(map_test_um)

# %%
x_axis = (map_test_um.columns * map_dx_v * x_sens_um).round(1)
y_axis = (map_test_um.index * map_dy_v * y_sens_um).round(1)

fig, ax = plt.subplots(figsize=(20, 10))  # Adjust the figsize as needed
a = sns.heatmap(map_test_um_zeroed, xticklabels=x_axis, yticklabels=y_axis, ax=ax)
a.invert_yaxis()

a.set_xlabel('X axis (um)')
a.set_ylabel('Y axis (um)')
a.set_title(f'Heatmap: {filename}')

colorbar = a.collections[0].colorbar
colorbar.set_label('Z axis (um)')
colorbar.ax.yaxis.label.set_rotation(90)  # Rotate the Z axis label
_ = plt.xticks(rotation=45)

# %%
x_axis = (map_test_um.columns * map_dx_v * x_sens_um).round(1)
y_axis = (map_test_um.index * map_dy_v * y_sens_um).round(1)

fig, ax = plt.subplots(figsize=(18, 9))  # Adjust the figsize as needed
a = sns.heatmap(map_test_um_zeroed, xticklabels=x_axis, yticklabels=y_axis, vmin=0, vmax=11)  # Set vmin and vmax as needed
a.invert_yaxis()

a.set_xlabel('X axis (um)')
a.set_ylabel('Y axis (um)')
a.set_title(f'Heatmap: {filename}')

a.set_aspect(y_sens_um/x_sens_um)

colorbar = a.collections[0].colorbar
colorbar.set_label('Z axis (um)')
colorbar.ax.yaxis.label.set_rotation(90)  # Rotate the Z axis label
_ = plt.xticks(rotation=45)

# %%
a = sns.heatmap(map_test_um,)
a.invert_yaxis()

# %%
# Calculate the dx_v and dy_v values given pixel size and max voltage
x_max_v = 6.27
x_pix = 32
dx = 0.14

y_max_v = 6.27
y_pix = 32

dx_v = x_max_v/(x_pix-1)
dy_v = y_max_v/(y_pix-1)

x_vs_y_ratio = x_sens_um/y_sens_um
dy = x_vs_y_ratio * dx

print(x_vs_y_ratio)
print (f'With a Vmax of {x_max_v}, Xpix: {x_pix}, and dx: {dx}, dy should be: {dy}')
# Out:
# 1.4356060606060606
# With a Vmax of 6.27, Xpix: 32, and dx: 0.14, dy should be: 0.2009848484848485

# %%
# Calculate the estimated time to do a map
time_per_fcurve = 0.2+0.1  # s

total_pixels = x_pix * y_pix
total_time = total_pixels * time_per_fcurve

total_time_min = total_time/60
print(f'Estimated total time for full curve: {total_time_min} min')
# Out:
# Estimated total time for full curve: 5.120000000000001 min

# %%
file_path = '/Users/evillz/Data/CTC44/2025_12_03/psnex_map___2025.03.12_18.23.11.20'

print (os.path.exists(file_path))
df_dict, map_x_pix, map_y_pix, params = maps.load_map_file_square_tdms(file_path)
_ = maps.create_heatmap(df_dict, params)
# Out:
# True
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[143], line 4
#       1 file_path = '/Users/evillz/Data/CTC44/2025_12_03/psnex_map___2025.03.12_18.23.11.20'
#       3 print (os.path.exists(file_path))
# ----> 4 df_dict, map_x_pix, map_y_pix, params = maps.load_map_file_square_tdms(file_path)
#       5 _ = maps.create_heatmap(df_dict, params)
#
# File ~/Github/PyFMGUI_DyNaMo_tdms/src/pyfmreader-dynamo/src/pyfmreader/ps_nex/loadpsnexMaps.py:658, in load_map_file_square_tdms(directory, key)
#     656 from pyfmreader.ps_nex.parseTDMS import grab_tdms
#     657 # Grab TDMS files
# --> 658 _, tdms_files = grab_tdms(directory)
#     660 # Open each force curve in the map and read the Zposition contact. If file is corrupt, NaN will be placed
#     661 data, map_x_pix, map_y_pix = extract_map_parameters(tdms_files, impulse_xy_v=0.1, estimate_xy=True)
#
# File ~/Github/PyFMGUI_DyNaMo_tdms/src/pyfmreader-dynamo/src/pyfmreader/ps_nex/parseTDMS.py:48, in grab_tdms(directory)
#      46 # select the first file
#      47 if not all_tdms:
# ---> 48     raise FileNotFoundError("No .tdms files found in the directory")
#      49 first_file = all_tdms[0]
#      50 # return the first file and all the list to facilitate the navigation
#
# FileNotFoundError: No .tdms files found in the directory

# %%
map_path ='/Users/evillz/Data/psnex_map___2025.03.12_18.23.11.20.map/CTC45_map1_PFQNM.csv'
map_path = '/Users/evillz/Data/CTC44/2025_12_03/psnex_map___2025.03.12_18.05.10.71/CTC45_map1_PFQNM.csv'

_ = maps.load_2d_map_file_csv(map_path, zmax=10)
_ = maps.compute_time_difference(os.path.dirname(map_path))
# Out:
# Analyzing map: /Users/evillz/Data/CTC44/2025_12_03/psnex_map___2025.03.12_18.05.10.71/CTC45_map1_PFQNM.csv
# y_sens_um: 3.96, x_sens_um: 5.685
# Files processed: 1022, matches found: 1022
#
# Time difference between first and last file HH:MM:SS:MS: 00:10:22:20

# %%
# _ = maps.compute_time_difference("/Users/evillz/Data/CTC44/2025_12_03/psnex_map___2025.03.12_17.51.51.34")

# _ = maps.compute_time_difference('/Users/evillz/Data/psnex_map___2025.03.12_18.23.11.20.map')
# Out:
# Files processed: 1024, matches found: 1024
#
# Time difference between first and last file HH:MM:SS:MS: 00:09:27:23
# Files processed: 0, matches found: 0
# Not enough files to compute a time difference.

# %%
_ = maps.compute_time_difference('/Users/evillz/Data/article/2025_30_5/psnex_map___2025.05.30_17.44.50.71')

save_path = '/Users/evillz/Data/article/2025_30_5/psnex_map___2025.05.30_17.44.50.71/results'

print (os.path.join(save_path, 'results',  'predicted_map.svg'))


df_map_csv, x_axis, y_axis = maps.load_2d_map_file_csv('/Users/evillz/Data/article/2025_30_5/psnex_map___2025.05.30_17.44.50.71/analysis/psnex_map___2025.05.30_17.44.50.71_predicted.csv',
                                                       save_svg= False, svg_path= os.path.join(save_path, 'results')+ 'predicted_map.svg', zmax = 10
                                                       
                                                       
                                                       
                            
                                                       
                                                       )
# Out:
# Files processed: 1024, matches found: 1024
#
# Time difference between first and last file HH:MM:SS:MS: 00:19:52:36
# /Users/evillz/Data/article/2025_30_5/psnex_map___2025.05.30_17.44.50.71/results/results/predicted_map.svg
# Analyzing map: /Users/evillz/Data/article/2025_30_5/psnex_map___2025.05.30_17.44.50.71/analysis/psnex_map___2025.05.30_17.44.50.71_predicted.csv
# y_sens_um: 3.96, x_sens_um: 5.685

# %% [markdown]
# Normal approach took 8min 15sec

# %%
_ = maps.load_2d_map_file_csv('/Users/evillz/Data/CTC44/2025_12_03/psnex_map___2025.03.12_18.38.42.45/CTC45_map1_PFQNM.csv')
# Out:
# Analyzing map: /Users/evillz/Data/CTC44/2025_12_03/psnex_map___2025.03.12_18.38.42.45/CTC45_map1_PFQNM.csv
# y_sens_um: 3.96, x_sens_um: 5.685

# %%
_ = maps.load_2d_map_file_csv('/Users/evillz/Data/CTC44/2025_12_03/psnex_map___2025.03.12_19.02.17.49/CTC45_map1_PFQNM.csv')
# Out:
# Analyzing map: /Users/evillz/Data/CTC44/2025_12_03/psnex_map___2025.03.12_19.02.17.49/CTC45_map1_PFQNM.csv
# y_sens_um: 3.96, x_sens_um: 5.685

# %%
_ = maps.load_2d_map_file_csv('/Users/evillz/Data/CTC44/2025_12_03/psnex_map___2025.03.12_18.23.11.20/CTC45_map1_PFQNM.csv')
# Out:
# Analyzing map: /Users/evillz/Data/CTC44/2025_12_03/psnex_map___2025.03.12_18.23.11.20/CTC45_map1_PFQNM.csv
# y_sens_um: 3.96, x_sens_um: 5.685

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import os
import pyfmreader as pyfm
import pyfmreader.ps_nex.parseTDMS as tdms
import numpy as np
import pyfmreader.ps_nex.loadpsnexMaps as maps
# map_path = '/Volumes/SSK_Drive/2025_11_06/psnex_map___2025.06.11_17.31.37.82'

# %%
# get all folders that start with 'psnex_map__'
import glob
import os
# Define the directory path
file_path = '/Volumes/SSK_Drive/golden_map'
# get folder names that start with 'psnex_map__'
map_folders = glob.glob(os.path.join(file_path, 'psnex_map__*'))
print (map_folders)
# Out:
# ['/Volumes/SSK_Drive/golden_map/psnex_map___2025.03.12_18.38.42.45']

# %%
for folder in map_folders:
    print (f'curent folder: {folder}')
    _ = maps.checkMapFileNULL(folder, CSVfile=True)
    df_dict, map_x_pix, map_y_pix, params = maps.load_map_file_square_tdms(folder)
    try: 
        _ = maps.create_heatmap(df_dict, params, save_svg=True)
    except Exception as e:  
        print(f"Error creating heatmap for {folder}: {e}")
# Out:
# curent folder: /Volumes/SSK_Drive/golden_map/psnex_map___2025.03.12_18.38.42.45
# processing file : /Volumes/SSK_Drive/golden_map/psnex_map___2025.03.12_18.38.42.45
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e039460>
# segment duration 3.82632,
#  numb of point cal (ticks, dec, sampling rate 23914, num pts stored per segment 23914
# segment duration 4.239059999999999,
#  numb of point cal (ticks, dec, sampling rate 26494, num pts stored per segment 26492
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f1951c0>
# segment duration 3.8515099999999998,
#  numb of point cal (ticks, dec, sampling rate 24071, num pts stored per segment 24071
# segment duration 4.243512,
#  numb of point cal (ticks, dec, sampling rate 26521, num pts stored per segment 26520
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17fd3ac70>
# segment duration 4.040252,
#  numb of point cal (ticks, dec, sampling rate 25251, num pts stored per segment 25251
# segment duration 4.344186,
#  numb of point cal (ticks, dec, sampling rate 27151, num pts stored per segment 27149
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f5955e0>
# segment duration 3.9409479999999997,
#  numb of point cal (ticks, dec, sampling rate 24630, num pts stored per segment 24630
# segment duration 4.35457,
#  numb of point cal (ticks, dec, sampling rate 27216, num pts stored per segment 27214
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f1952e0>
# segment duration 4.066624,
#  numb of point cal (ticks, dec, sampling rate 25416, num pts stored per segment 25416
# segment duration 4.401918,
#  numb of point cal (ticks, dec, sampling rate 27511, num pts stored per segment 27510
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x16a610280>
# segment duration 3.866192,
#  numb of point cal (ticks, dec, sampling rate 24163, num pts stored per segment 24163
# segment duration 4.343248,
#  numb of point cal (ticks, dec, sampling rate 27145, num pts stored per segment 27143
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e01b520>
# segment duration 3.873748,
#  numb of point cal (ticks, dec, sampling rate 24210, num pts stored per segment 24210
# segment duration 4.31968,
#  numb of point cal (ticks, dec, sampling rate 26998, num pts stored per segment 26996
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e384040>
# segment duration 4.001113999999999,
#  numb of point cal (ticks, dec, sampling rate 25006, num pts stored per segment 25006
# segment duration 4.374092,
#  numb of point cal (ticks, dec, sampling rate 27338, num pts stored per segment 27336
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f566700>
# segment duration 3.88358,
#  numb of point cal (ticks, dec, sampling rate 24272, num pts stored per segment 24272
# segment duration 4.337306,
#  numb of point cal (ticks, dec, sampling rate 27108, num pts stored per segment 27106
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x319064280>
# segment duration 3.716032,
#  numb of point cal (ticks, dec, sampling rate 23225, num pts stored per segment 23224
# segment duration 4.23077,
#  numb of point cal (ticks, dec, sampling rate 26442, num pts stored per segment 26440
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f595880>
# segment duration 3.64953,
#  numb of point cal (ticks, dec, sampling rate 22809, num pts stored per segment 22809
# segment duration 4.132822,
#  numb of point cal (ticks, dec, sampling rate 25830, num pts stored per segment 25828
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f800730>
# segment duration 3.622448,
#  numb of point cal (ticks, dec, sampling rate 22640, num pts stored per segment 22639
# segment duration 3.99763,
#  numb of point cal (ticks, dec, sampling rate 24985, num pts stored per segment 24983
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f195190>
# segment duration 3.566686,
#  numb of point cal (ticks, dec, sampling rate 22291, num pts stored per segment 22291
# segment duration 4.029938,
#  numb of point cal (ticks, dec, sampling rate 25187, num pts stored per segment 25185
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x319064160>
# segment duration 3.726282,
#  numb of point cal (ticks, dec, sampling rate 23289, num pts stored per segment 23288
# segment duration 4.0363679999999995,
#  numb of point cal (ticks, dec, sampling rate 25227, num pts stored per segment 25225
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e384130>
# segment duration 3.632304,
#  numb of point cal (ticks, dec, sampling rate 22701, num pts stored per segment 22701
# segment duration 4.015222,
#  numb of point cal (ticks, dec, sampling rate 25095, num pts stored per segment 25093
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f5955e0>
# segment duration 2.279482,
#  numb of point cal (ticks, dec, sampling rate 14246, num pts stored per segment 14246
# segment duration 2.440012,
#  numb of point cal (ticks, dec, sampling rate 15250, num pts stored per segment 15248
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x16a610af0>
# segment duration 3.60235,
#  numb of point cal (ticks, dec, sampling rate 22514, num pts stored per segment 22514
# segment duration 3.98546,
#  numb of point cal (ticks, dec, sampling rate 24909, num pts stored per segment 24907
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x319064220>
# segment duration 2.29656,
#  numb of point cal (ticks, dec, sampling rate 14353, num pts stored per segment 14353
# segment duration 2.3937839999999997,
#  numb of point cal (ticks, dec, sampling rate 14961, num pts stored per segment 14959
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f800190>
# segment duration 1.839524,
#  numb of point cal (ticks, dec, sampling rate 11497, num pts stored per segment 11496
# segment duration 2.8240119999999997,
#  numb of point cal (ticks, dec, sampling rate 17650, num pts stored per segment 17648
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f595550>
# segment duration 1.484526,
#  numb of point cal (ticks, dec, sampling rate 9278, num pts stored per segment 9277
# segment duration 3.397154,
#  numb of point cal (ticks, dec, sampling rate 21232, num pts stored per segment 21230
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f664d00>
# segment duration 2.14241,
#  numb of point cal (ticks, dec, sampling rate 13390, num pts stored per segment 13389
# segment duration 2.205454,
#  numb of point cal (ticks, dec, sampling rate 13784, num pts stored per segment 13782
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x319064220>
# segment duration 1.233326,
#  numb of point cal (ticks, dec, sampling rate 7708, num pts stored per segment 7707
# segment duration 5.354292,
#  numb of point cal (ticks, dec, sampling rate 33464, num pts stored per segment 33462
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f664fd0>
# segment duration 2.036518,
#  numb of point cal (ticks, dec, sampling rate 12728, num pts stored per segment 12727
# segment duration 2.093184,
#  numb of point cal (ticks, dec, sampling rate 13082, num pts stored per segment 13080
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e01b520>
# segment duration 1.080166,
#  numb of point cal (ticks, dec, sampling rate 6751, num pts stored per segment 6750
# segment duration 4.895224,
#  numb of point cal (ticks, dec, sampling rate 30595, num pts stored per segment 30593
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f664610>
# segment duration 1.161098,
#  numb of point cal (ticks, dec, sampling rate 7256, num pts stored per segment 7256
# segment duration 5.475384,
#  numb of point cal (ticks, dec, sampling rate 34221, num pts stored per segment 34219
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f195040>
# segment duration 1.287466,
#  numb of point cal (ticks, dec, sampling rate 8046, num pts stored per segment 8046
# segment duration 6.181286,
#  numb of point cal (ticks, dec, sampling rate 38633, num pts stored per segment 38631
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x107ab2e80>
# segment duration 0.954108,
#  numb of point cal (ticks, dec, sampling rate 5963, num pts stored per segment 5962
# segment duration 4.129322,
#  numb of point cal (ticks, dec, sampling rate 25808, num pts stored per segment 25806
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f800c10>
# segment duration 1.6403379999999999,
#  numb of point cal (ticks, dec, sampling rate 10252, num pts stored per segment 10251
# segment duration 8.312534,
#  numb of point cal (ticks, dec, sampling rate 51953, num pts stored per segment 51951
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e01b520>
# segment duration 1.50646,
#  numb of point cal (ticks, dec, sampling rate 9415, num pts stored per segment 9415
# segment duration 7.384328,
#  numb of point cal (ticks, dec, sampling rate 46152, num pts stored per segment 46150
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x319052c10>
# segment duration 1.4387699999999999,
#  numb of point cal (ticks, dec, sampling rate 8992, num pts stored per segment 8991
# segment duration 7.102098,
#  numb of point cal (ticks, dec, sampling rate 44388, num pts stored per segment 44386
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f5957f0>
# segment duration 1.7040899999999999,
#  numb of point cal (ticks, dec, sampling rate 10650, num pts stored per segment 10650
# segment duration 8.664325999999999,
#  numb of point cal (ticks, dec, sampling rate 54152, num pts stored per segment 54150
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f566100>
# segment duration 1.803162,
#  numb of point cal (ticks, dec, sampling rate 11269, num pts stored per segment 11269
# segment duration 9.198891999999999,
#  numb of point cal (ticks, dec, sampling rate 57493, num pts stored per segment 57491
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f8ad550>
# segment duration 1.746294,
#  numb of point cal (ticks, dec, sampling rate 10914, num pts stored per segment 10913
# segment duration 8.86436,
#  numb of point cal (ticks, dec, sampling rate 55402, num pts stored per segment 55400
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x319064280>
# segment duration 3.639186,
#  numb of point cal (ticks, dec, sampling rate 22744, num pts stored per segment 22744
# segment duration 19.865002,
#  numb of point cal (ticks, dec, sampling rate 124156, num pts stored per segment 124154
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e01bfa0>
# segment duration 3.662506,
#  numb of point cal (ticks, dec, sampling rate 22890, num pts stored per segment 22890
# segment duration 8.605172,
#  numb of point cal (ticks, dec, sampling rate 53782, num pts stored per segment 53780
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e0391f0>
# segment duration 3.8739399999999997,
#  numb of point cal (ticks, dec, sampling rate 24212, num pts stored per segment 24211
# segment duration 19.65139,
#  numb of point cal (ticks, dec, sampling rate 122821, num pts stored per segment 122819
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f5957c0>
# segment duration 3.9219459999999997,
#  numb of point cal (ticks, dec, sampling rate 24512, num pts stored per segment 24511
# segment duration 4.335214,
#  numb of point cal (ticks, dec, sampling rate 27095, num pts stored per segment 27093
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e01b7c0>
# segment duration 3.8219239999999997,
#  numb of point cal (ticks, dec, sampling rate 23887, num pts stored per segment 23886
# segment duration 4.348485999999999,
#  numb of point cal (ticks, dec, sampling rate 27178, num pts stored per segment 27176
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e01bfa0>
# segment duration 4.1423499999999995,
#  numb of point cal (ticks, dec, sampling rate 25889, num pts stored per segment 25889
# segment duration 4.439736,
#  numb of point cal (ticks, dec, sampling rate 27748, num pts stored per segment 27746
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e4625e0>
# segment duration 3.679798,
#  numb of point cal (ticks, dec, sampling rate 22998, num pts stored per segment 22998
# segment duration 4.034596,
#  numb of point cal (ticks, dec, sampling rate 25216, num pts stored per segment 25214
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e462790>
# segment duration 3.7842979999999997,
#  numb of point cal (ticks, dec, sampling rate 23651, num pts stored per segment 23651
# segment duration 4.251384,
#  numb of point cal (ticks, dec, sampling rate 26571, num pts stored per segment 26569
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17fd3a700>
# segment duration 3.778568,
#  numb of point cal (ticks, dec, sampling rate 23616, num pts stored per segment 23615
# segment duration 4.321442,
#  numb of point cal (ticks, dec, sampling rate 27009, num pts stored per segment 27007
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e4627c0>
# segment duration 3.466844,
#  numb of point cal (ticks, dec, sampling rate 21667, num pts stored per segment 21667
# segment duration 4.054422,
#  numb of point cal (ticks, dec, sampling rate 25340, num pts stored per segment 25338
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f664fd0>
# segment duration 3.640342,
#  numb of point cal (ticks, dec, sampling rate 22752, num pts stored per segment 22751
# segment duration 3.4097619999999997,
#  numb of point cal (ticks, dec, sampling rate 21311, num pts stored per segment 21309
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x319052520>
# segment duration 3.734492,
#  numb of point cal (ticks, dec, sampling rate 23340, num pts stored per segment 23340
# segment duration 3.414742,
#  numb of point cal (ticks, dec, sampling rate 21342, num pts stored per segment 21340
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x31905f190>
# segment duration 3.7056039999999997,
#  numb of point cal (ticks, dec, sampling rate 23160, num pts stored per segment 23159
# segment duration 2.972666,
#  numb of point cal (ticks, dec, sampling rate 18579, num pts stored per segment 18577
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f5957c0>
# segment duration 2.5065679999999997,
#  numb of point cal (ticks, dec, sampling rate 15666, num pts stored per segment 15665
# segment duration 1.604844,
#  numb of point cal (ticks, dec, sampling rate 10030, num pts stored per segment 10028
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x31905fcd0>
# segment duration 2.66409,
#  numb of point cal (ticks, dec, sampling rate 16650, num pts stored per segment 16650
# segment duration 1.54913,
#  numb of point cal (ticks, dec, sampling rate 9682, num pts stored per segment 9680
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x319064160>
# segment duration 2.43209,
#  numb of point cal (ticks, dec, sampling rate 15200, num pts stored per segment 15200
# segment duration 1.423222,
#  numb of point cal (ticks, dec, sampling rate 8895, num pts stored per segment 8893
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e384040>
# segment duration 2.4572499999999997,
#  numb of point cal (ticks, dec, sampling rate 15357, num pts stored per segment 15357
# segment duration 1.423544,
#  numb of point cal (ticks, dec, sampling rate 8897, num pts stored per segment 8895
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e462b50>
# segment duration 2.2731559999999997,
#  numb of point cal (ticks, dec, sampling rate 14207, num pts stored per segment 14206
# segment duration 1.31622,
#  numb of point cal (ticks, dec, sampling rate 8226, num pts stored per segment 8224
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f664fd0>
# segment duration 2.3672459999999997,
#  numb of point cal (ticks, dec, sampling rate 14795, num pts stored per segment 14794
# segment duration 1.3822619999999999,
#  numb of point cal (ticks, dec, sampling rate 8639, num pts stored per segment 8637
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e01b7c0>
# segment duration 2.3377079999999997,
#  numb of point cal (ticks, dec, sampling rate 14610, num pts stored per segment 14610
# segment duration 1.3765319999999999,
#  numb of point cal (ticks, dec, sampling rate 8603, num pts stored per segment 8601
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e3cdc10>
# segment duration 2.119374,
#  numb of point cal (ticks, dec, sampling rate 13246, num pts stored per segment 13245
# segment duration 1.194436,
#  numb of point cal (ticks, dec, sampling rate 7465, num pts stored per segment 7463
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f566700>
# segment duration 1.7820019999999999,
#  numb of point cal (ticks, dec, sampling rate 11137, num pts stored per segment 11137
# segment duration 1.000186,
#  numb of point cal (ticks, dec, sampling rate 6251, num pts stored per segment 6249
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e3cdbb0>
# segment duration 1.878566,
#  numb of point cal (ticks, dec, sampling rate 11741, num pts stored per segment 11740
# segment duration 1.04164,
#  numb of point cal (ticks, dec, sampling rate 6510, num pts stored per segment 6508
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f800190>
# segment duration 1.910224,
#  numb of point cal (ticks, dec, sampling rate 11938, num pts stored per segment 11938
# segment duration 1.101602,
#  numb of point cal (ticks, dec, sampling rate 6885, num pts stored per segment 6883
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e462e20>
# segment duration 1.839426,
#  numb of point cal (ticks, dec, sampling rate 11496, num pts stored per segment 11496
# segment duration 1.041502,
#  numb of point cal (ticks, dec, sampling rate 6509, num pts stored per segment 6507
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e3cd970>
# segment duration 1.9109099999999999,
#  numb of point cal (ticks, dec, sampling rate 11943, num pts stored per segment 11942
# segment duration 1.084984,
#  numb of point cal (ticks, dec, sampling rate 6781, num pts stored per segment 6779
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f664ee0>
# segment duration 1.903122,
#  numb of point cal (ticks, dec, sampling rate 11894, num pts stored per segment 11894
# segment duration 1.081636,
#  numb of point cal (ticks, dec, sampling rate 6760, num pts stored per segment 6758
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x16a610af0>
# segment duration 1.811736,
#  numb of point cal (ticks, dec, sampling rate 11323, num pts stored per segment 11322
# segment duration 1.02902,
#  numb of point cal (ticks, dec, sampling rate 6431, num pts stored per segment 6429
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x319052c10>
# segment duration 1.8494819999999998,
#  numb of point cal (ticks, dec, sampling rate 11559, num pts stored per segment 11558
# segment duration 1.043844,
#  numb of point cal (ticks, dec, sampling rate 6524, num pts stored per segment 6522
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e4628b0>
# segment duration 1.9324,
#  numb of point cal (ticks, dec, sampling rate 12077, num pts stored per segment 12077
# segment duration 1.112164,
#  numb of point cal (ticks, dec, sampling rate 6951, num pts stored per segment 6949
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e462640>
# segment duration 2.049014,
#  numb of point cal (ticks, dec, sampling rate 12806, num pts stored per segment 12805
# segment duration 1.1926539999999999,
#  numb of point cal (ticks, dec, sampling rate 7454, num pts stored per segment 7452
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x16a7aaca0>
# segment duration 3.958744,
#  numb of point cal (ticks, dec, sampling rate 24742, num pts stored per segment 24741
# segment duration 2.425172,
#  numb of point cal (ticks, dec, sampling rate 15157, num pts stored per segment 15155
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x319052c10>
# segment duration 4.155476,
#  numb of point cal (ticks, dec, sampling rate 25971, num pts stored per segment 25971
# segment duration 2.4809699999999997,
#  numb of point cal (ticks, dec, sampling rate 15506, num pts stored per segment 15504
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f195190>
# segment duration 4.2716259999999995,
#  numb of point cal (ticks, dec, sampling rate 26697, num pts stored per segment 26697
# segment duration 2.51825,
#  numb of point cal (ticks, dec, sampling rate 15739, num pts stored per segment 15737
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e462a60>
# segment duration 3.881318,
#  numb of point cal (ticks, dec, sampling rate 24258, num pts stored per segment 24257
# segment duration 2.45476,
#  numb of point cal (ticks, dec, sampling rate 15342, num pts stored per segment 15340
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e462340>
# segment duration 3.8666859999999996,
#  numb of point cal (ticks, dec, sampling rate 24166, num pts stored per segment 24166
# segment duration 2.416686,
#  numb of point cal (ticks, dec, sampling rate 15104, num pts stored per segment 15102
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x107ab2e80>
# segment duration 3.8815779999999998,
#  numb of point cal (ticks, dec, sampling rate 24259, num pts stored per segment 24259
# segment duration 2.39603,
#  numb of point cal (ticks, dec, sampling rate 14975, num pts stored per segment 14973
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e3cda00>
# segment duration 3.963256,
#  numb of point cal (ticks, dec, sampling rate 24770, num pts stored per segment 24769
# segment duration 2.419838,
#  numb of point cal (ticks, dec, sampling rate 15123, num pts stored per segment 15122
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f664ee0>
# segment duration 3.96853,
#  numb of point cal (ticks, dec, sampling rate 24803, num pts stored per segment 24802
# segment duration 2.41124,
#  numb of point cal (ticks, dec, sampling rate 15070, num pts stored per segment 15068
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e462730>
# segment duration 3.933632,
#  numb of point cal (ticks, dec, sampling rate 24585, num pts stored per segment 24584
# segment duration 2.397954,
#  numb of point cal (ticks, dec, sampling rate 14987, num pts stored per segment 14985
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f566700>
# segment duration 3.9007639999999997,
#  numb of point cal (ticks, dec, sampling rate 24379, num pts stored per segment 24379
# segment duration 2.384986,
#  numb of point cal (ticks, dec, sampling rate 14906, num pts stored per segment 14904
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e462be0>
# segment duration 3.8798719999999998,
#  numb of point cal (ticks, dec, sampling rate 24249, num pts stored per segment 24248
# segment duration 2.385456,
#  numb of point cal (ticks, dec, sampling rate 14909, num pts stored per segment 14907
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17fd3a700>
# segment duration 3.8158879999999997,
#  numb of point cal (ticks, dec, sampling rate 23849, num pts stored per segment 23848
# segment duration 2.39445,
#  numb of point cal (ticks, dec, sampling rate 14965, num pts stored per segment 14963
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x16ff99bb0>
# segment duration 4.011506,
#  numb of point cal (ticks, dec, sampling rate 25071, num pts stored per segment 25071
# segment duration 2.438244,
#  numb of point cal (ticks, dec, sampling rate 15239, num pts stored per segment 15237
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x16ff99ac0>
# segment duration 3.37405,
#  numb of point cal (ticks, dec, sampling rate 21087, num pts stored per segment 21087
# segment duration 2.0124839999999997,
#  numb of point cal (ticks, dec, sampling rate 12578, num pts stored per segment 12576
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e3cd970>
# segment duration 3.673952,
#  numb of point cal (ticks, dec, sampling rate 22962, num pts stored per segment 22961
# segment duration 2.311706,
#  numb of point cal (ticks, dec, sampling rate 14448, num pts stored per segment 14446
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e462910>
# segment duration 3.75594,
#  numb of point cal (ticks, dec, sampling rate 23474, num pts stored per segment 23474
# segment duration 2.353592,
#  numb of point cal (ticks, dec, sampling rate 14709, num pts stored per segment 14708
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f664ee0>
# segment duration 2.6507479999999997,
#  numb of point cal (ticks, dec, sampling rate 16567, num pts stored per segment 16566
# segment duration 1.4964819999999999,
#  numb of point cal (ticks, dec, sampling rate 9353, num pts stored per segment 9351
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e01bfa0>
# segment duration 2.320276,
#  numb of point cal (ticks, dec, sampling rate 14501, num pts stored per segment 14501
# segment duration 1.350442,
#  numb of point cal (ticks, dec, sampling rate 8440, num pts stored per segment 8438
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x31905f130>
# segment duration 2.304274,
#  numb of point cal (ticks, dec, sampling rate 14401, num pts stored per segment 14401
# segment duration 1.3501239999999999,
#  numb of point cal (ticks, dec, sampling rate 8438, num pts stored per segment 8436
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f566700>
# segment duration 2.3731619999999998,
#  numb of point cal (ticks, dec, sampling rate 14832, num pts stored per segment 14831
# segment duration 1.375092,
#  numb of point cal (ticks, dec, sampling rate 8594, num pts stored per segment 8592
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x16a61d2b0>
# segment duration 2.282974,
#  numb of point cal (ticks, dec, sampling rate 14268, num pts stored per segment 14268
# segment duration 1.32704,
#  numb of point cal (ticks, dec, sampling rate 8294, num pts stored per segment 8292
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x31905f190>
# segment duration 1.9152339999999999,
#  numb of point cal (ticks, dec, sampling rate 11970, num pts stored per segment 11969
# segment duration 1.094304,
#  numb of point cal (ticks, dec, sampling rate 6839, num pts stored per segment 6837
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x16ff99c70>
# segment duration 1.9454019999999999,
#  numb of point cal (ticks, dec, sampling rate 12158, num pts stored per segment 12158
# segment duration 1.086748,
#  numb of point cal (ticks, dec, sampling rate 6792, num pts stored per segment 6790
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e384040>
# segment duration 2.074558,
#  numb of point cal (ticks, dec, sampling rate 12965, num pts stored per segment 12965
# segment duration 1.21238,
#  numb of point cal (ticks, dec, sampling rate 7577, num pts stored per segment 7575
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x16a61d2b0>
# segment duration 2.193562,
#  numb of point cal (ticks, dec, sampling rate 13709, num pts stored per segment 13709
# segment duration 1.247568,
#  numb of point cal (ticks, dec, sampling rate 7797, num pts stored per segment 7795
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f800df0>
# segment duration 1.901044,
#  numb of point cal (ticks, dec, sampling rate 11881, num pts stored per segment 11881
# segment duration 1.068652,
#  numb of point cal (ticks, dec, sampling rate 6679, num pts stored per segment 6677
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e0395b0>
# segment duration 2.022538,
#  numb of point cal (ticks, dec, sampling rate 12640, num pts stored per segment 12640
# segment duration 1.152358,
#  numb of point cal (ticks, dec, sampling rate 7202, num pts stored per segment 7200
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f800190>
# segment duration 1.8283019999999999,
#  numb of point cal (ticks, dec, sampling rate 11426, num pts stored per segment 11426
# segment duration 1.04433,
#  numb of point cal (ticks, dec, sampling rate 6527, num pts stored per segment 6525
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x319064160>
# segment duration 1.783788,
#  numb of point cal (ticks, dec, sampling rate 11148, num pts stored per segment 11148
# segment duration 1.0037099999999999,
#  numb of point cal (ticks, dec, sampling rate 6273, num pts stored per segment 6271
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x31905f190>
# segment duration 1.78361,
#  numb of point cal (ticks, dec, sampling rate 11147, num pts stored per segment 11147
# segment duration 0.997606,
#  numb of point cal (ticks, dec, sampling rate 6235, num pts stored per segment 6233
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x31905fcd0>
# segment duration 4.154006,
#  numb of point cal (ticks, dec, sampling rate 25962, num pts stored per segment 25962
# segment duration 2.51985,
#  numb of point cal (ticks, dec, sampling rate 15749, num pts stored per segment 15747
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f800460>
# segment duration 4.153326,
#  numb of point cal (ticks, dec, sampling rate 25958, num pts stored per segment 25957
# segment duration 2.48975,
#  numb of point cal (ticks, dec, sampling rate 15560, num pts stored per segment 15559
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e3cdc10>
# segment duration 1.8041079999999998,
#  numb of point cal (ticks, dec, sampling rate 11275, num pts stored per segment 11275
# segment duration 1.013314,
#  numb of point cal (ticks, dec, sampling rate 6333, num pts stored per segment 6331
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e3cda90>
# segment duration 4.3334019999999995,
#  numb of point cal (ticks, dec, sampling rate 27083, num pts stored per segment 27083
# segment duration 2.540994,
#  numb of point cal (ticks, dec, sampling rate 15881, num pts stored per segment 15879
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f566700>
# segment duration 4.190554,
#  numb of point cal (ticks, dec, sampling rate 26190, num pts stored per segment 26190
# segment duration 2.540826,
#  numb of point cal (ticks, dec, sampling rate 15880, num pts stored per segment 15878
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x16a61d2b0>
# segment duration 3.774088,
#  numb of point cal (ticks, dec, sampling rate 23588, num pts stored per segment 23587
# segment duration 2.438732,
#  numb of point cal (ticks, dec, sampling rate 15242, num pts stored per segment 15240
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e0391f0>
# segment duration 3.9167739999999998,
#  numb of point cal (ticks, dec, sampling rate 24479, num pts stored per segment 24479
# segment duration 2.4166939999999997,
#  numb of point cal (ticks, dec, sampling rate 15104, num pts stored per segment 15102
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e4626a0>
# segment duration 3.5022499999999996,
#  numb of point cal (ticks, dec, sampling rate 21889, num pts stored per segment 21888
# segment duration 2.15333,
#  numb of point cal (ticks, dec, sampling rate 13458, num pts stored per segment 13456
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x31905f130>
# segment duration 3.956546,
#  numb of point cal (ticks, dec, sampling rate 24728, num pts stored per segment 24728
# segment duration 2.357326,
#  numb of point cal (ticks, dec, sampling rate 14733, num pts stored per segment 14731
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e384040>
# segment duration 3.7741919999999998,
#  numb of point cal (ticks, dec, sampling rate 23588, num pts stored per segment 23588
# segment duration 2.367094,
#  numb of point cal (ticks, dec, sampling rate 14794, num pts stored per segment 14792
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x16a610af0>
# segment duration 3.8543079999999996,
#  numb of point cal (ticks, dec, sampling rate 24089, num pts stored per segment 24089
# segment duration 2.3611519999999997,
#  numb of point cal (ticks, dec, sampling rate 14757, num pts stored per segment 14755
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17f800190>
# segment duration 3.744662,
#  numb of point cal (ticks, dec, sampling rate 23404, num pts stored per segment 23403
# segment duration 2.330122,
#  numb of point cal (ticks, dec, sampling rate 14563, num pts stored per segment 14561
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e01bfa0>
# segment duration 4.043822,
#  numb of point cal (ticks, dec, sampling rate 25273, num pts stored per segment 25273
# segment duration 2.447834,
#  numb of point cal (ticks, dec, sampling rate 15298, num pts stored per segment 15297
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x319052d30>
# segment duration 3.624446,
#  numb of point cal (ticks, dec, sampling rate 22652, num pts stored per segment 22652
# segment duration 2.32803,
#  numb of point cal (ticks, dec, sampling rate 14550, num pts stored per segment 14548
# df_point log made
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# <pyfmreader.utils.forcecurve.ForceCurve object at 0x17e462a90>
# segment duration 4.047756,
#  numb of point cal (ticks, dec, sampling rate 25298, num pts stored per segment 25298
# segment duration 2.415872,
#  numb of point cal (ticks, dec, sampling rate 15099, num pts stored per segment 15097
# ...
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
#  map metadata: map_x_step: 0.143, map_y_step: 0.200001, map_x_init: 0.0, map_y_init: 0.0
#  x_sens (um/V): 5.685, y_sens (um/V): 3.96, z_sens (um/V): 6.0, z_setpoint_trig (V): 4.881134
# ⚠️  Missing metadata key: 'mapping_X_pixel' - using default: 0
# ⚠️  Missing metadata key: 'mapping_Y_pixel' - using default: 0
# Warning: Data length 1007 does not match expected size 1024. Adjusting map dimensions.
# Added 17 NaN values to fit the shape.
# Adjusted shape: 32 x 32
# Using provided DataFrame for heatmap
# Error creating heatmap for /Volumes/SSK_Drive/golden_map/psnex_map___2025.03.12_18.38.42.45: cannot convert float NaN to integer
